# %% [markdown]
# ## Projeto da aula de data sience em 2025:

# %% [markdown]
# # ADICIONAR A ORIGEM DOS DADOS
# Este projeto faz parte da disciplina **Ciência de Dados (2025/1)** do **Instituto Federal de Rondônia**. A matéria é ministrada pelo professor [José Lucas Brandão Montes](https://github.com/zehlucas).
#
# Existe [outro projeto associado à disciplina](https://github.com/zehlucas/IFRO-ADS-DataScience-2025), mantido pelo professor, que contém os códigos utilizados em aula para auxiliar os alunos no acompanhamento do conteúdo.
#
# Optei por não seguir exatamente o formato proposto, pois o professor deixou essa escolha em aberto. Sinta-se à vontade para explorar este projeto e, caso tenha alguma dúvida, pode entrar em contato comigo.

# %% [markdown]
# ## Configuração do ambiente:

# %%
# Função shell que descomprime os arquivos zip

# Criando a pasta csv caso não exita
# !mkdir -p ./csv

# Acessando a pasta dos zips e iterando os arquivos
# !cd zips && for file in *.zip; do \
    # Descompactando os arquivos zip com o nome temp_extract
    unzip -o "$file" -d temp_extract && \
    # Movendo ele para a pasta csv
    mv temp_extract/*.csv ../csv/ && \
    # Limpando o que eu descomprimir
    rm -r temp_extract; \
done
# Out:
# Archive:  acidentes_2022.zip
#   inflating: temp_extract/acidentes_2022.csv
# Archive:  localidades_2022.zip
#   inflating: temp_extract/localidades_2022.csv
# Archive:  tipo_veiculo.zip
#   inflating: temp_extract/tipo_veiculo.csv.csv
# Archive:  vitimas_2022.zip
#   inflating: temp_extract/vitimas_2022.csv

# %%
# Renomeando o csv por ele veio com o nome errado!
# !mv csv/tipo_veiculo.csv.csv csv/tipo_veiculo.csv

# %%
# Adicionando as dependecias!
# !pip freeze > requirements.txt

# %%
# Instalando as dependencies
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==3.0.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: comm==0.2.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler==0.12.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.13 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: executing==2.2.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: fonttools==4.57.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.57.0)
# Requirement already satisfied: ipykernel==6.29.5 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (6.29.5)
# Requirement already satisfied: ipython==9.0.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (9.0.2)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.19.2)
# Requirement already satisfied: jupyter_client==8.6.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (5.7.2)
# Requirement already satisfied: kiwisolver==1.4.8 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.4.8)
# Requirement already satisfied: matplotlib==3.10.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (3.10.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (0.1.7)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: numpy==2.2.4 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (2.2.4)
# Requirement already satisfied: packaging==24.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (4.9.0)
# Requirement already satisfied: pillow==11.2.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (11.2.1)
# Requirement already satisfied: platformdirs==4.3.7 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (4.3.7)
# Requirement already satisfied: prompt_toolkit==3.0.50 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (3.0.50)
# Requirement already satisfied: psutil==7.0.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (0.2.3)
# Requirement already satisfied: Pygments==2.19.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (2.19.1)
# Requirement already satisfied: pyparsing==3.2.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (3.2.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (2025.2)
# Requirement already satisfied: pyzmq==26.3.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (26.3.0)
# Requirement already satisfied: six==1.17.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (1.17.0)
# Requirement already satisfied: stack-data==0.6.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (0.6.3)
# Requirement already satisfied: tornado==6.4.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (6.4.2)
# Requirement already satisfied: traitlets==5.14.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (5.14.3)
# Requirement already satisfied: tzdata==2025.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (2025.2)
# Requirement already satisfied: wcwidth==0.2.13 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (0.2.13)

# %% [markdown]
# ## Exploração dos dados:

# %% [markdown]
# #### Importado as dependencias:

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# #### Lendo os arquivos:

# %%
acidentes = pd.read_csv('./csv/acidentes_2022.csv')
localidades  = pd.read_csv('./csv/localidades_2022.csv')
tipo_veiculos = pd.read_csv('./csv/tipo_veiculo.csv')
vitimas = pd.read_csv('./csv/vitimas_2022.csv')
# Out:
# /tmp/ipykernel_842106/2929211778.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   acidentes = pd.read_csv('./csv/acidentes_2022.csv')

# %% [markdown]
# #### Explorando os acidentes:

# %%
acidentes.head(2)
# Out:
#    Unnamed: 0  num_acidente   chv_localidade data_acidente uf_acidente  \
# 0       16027       1676690  AC1200401202201    2022-01-21          AC
# 1       16028       4441865  AC1200401202201    2022-01-03          AC
#
#    ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge     dia_semana  \
# 0          2022             1             12022      1200401    SEXTA-FEIRA
# 1          2022             1             12022      1200401  SEGUNDA-FEIRA
#
#    ... lim_velocidade       tp_pista  ind_guardrail ind_cantcentral  \
# 0  ...  NAO INFORMADO  NAO INFORMADO  NAO INFORMADO   NAO INFORMADO
# 1  ...  NAO INFORMADO  NAO INFORMADO  NAO INFORMADO   NAO INFORMADO
#
#    ind_acostamento  qtde_acidente qtde_acid_com_obitos  qtde_envolvidos  \
# 0    NAO INFORMADO              1                    0                1
# 1    NAO INFORMADO              1                    0                2
#
#    qtde_feridosilesos  qtde_obitos
# 0                   1            0
# 1                   2            0
#
# [2 rows x 36 columns]

# %%
acidentes.describe()
# Out:
#          Unnamed: 0  num_acidente  ano_acidente   mes_acidente  \
# count  9.098320e+05  9.098320e+05      909832.0  909832.000000
# mean   2.571726e+06  2.291422e+06        2022.0       6.170250
# std    1.261638e+06  1.322318e+06           0.0       3.256915
# min    1.602700e+04  1.000000e+00        2022.0       1.000000
# 25%    2.028936e+06  1.147705e+06        2022.0       3.000000
# 50%    2.455882e+06  2.291814e+06        2022.0       6.000000
# 75%    3.707716e+06  3.433892e+06        2022.0       9.000000
# max    4.505901e+06  4.588682e+06        2022.0      12.000000
#
#        mes_ano_acidente   codigo_ibge  num_end_acidente  cep_acidente  \
# count     909832.000000  9.098320e+05     909832.000000  9.098320e+05
# mean       63724.501121  3.705230e+06       1765.380320  1.928220e+06
# std        32569.145539  9.780963e+05       8137.918993  9.963200e+06
# min        12022.000000  0.000000e+00          0.000000  0.000000e+00
# 25%        32022.000000  3.129806e+06          0.000000  0.000000e+00
# 50%        62022.000000  3.549805e+06          0.000000  0.000000e+00
# 75%        92022.000000  4.208906e+06        415.000000  0.000000e+00
# max       122022.000000  5.300108e+06      99999.000000  7.999500e+07
#
#        km_via_acidente  latitude_acidente  longitude_acidente  hora_acidente  \
# count    909832.000000      440368.000000       440278.000000  909832.000000
# mean          9.464107         -14.994373          -38.082897  149146.267508
# std          94.826551           7.636657           18.381816  119717.606350
# min           0.000000         -32.637774          -72.862854       0.000000
# 25%           0.000000         -19.928644          -48.247158  100000.000000
# 50%           0.000000         -18.885103          -44.019971  142500.000000
# 75%           0.000000         -15.316890          -42.604754  181300.000000
# max        9999.000000           4.595370           -0.000000  999999.000000
#
#        qtde_acidente  qtde_acid_com_obitos  qtde_envolvidos  \
# count       909832.0         909832.000000    909832.000000
# mean             1.0              0.019166         1.546953
# std              0.0              0.137109         1.010018
# min              1.0              0.000000         0.000000
# 25%              1.0              0.000000         1.000000
# 50%              1.0              0.000000         1.000000
# 75%              1.0              0.000000         2.000000
# max              1.0              1.000000        67.000000
#
#        qtde_feridosilesos    qtde_obitos
# count       909832.000000  909832.000000
# mean             1.526102       0.020851
# std              1.011363       0.158495
# min              0.000000       0.000000
# 25%              1.000000       0.000000
# 50%              1.000000       0.000000
# 75%              2.000000       0.000000
# max             67.000000      10.000000

# %%
acidentes.columns
# Out:
# Index(['Unnamed: 0', 'num_acidente', 'chv_localidade', 'data_acidente',
#        'uf_acidente', 'ano_acidente', 'mes_acidente', 'mes_ano_acidente',
#        'codigo_ibge', 'dia_semana', 'fase_dia', 'tp_acidente',
#        'cond_meteorologica', 'end_acidente', 'num_end_acidente',
#        'cep_acidente', 'bairro_acidente', 'km_via_acidente',
#        'latitude_acidente', 'longitude_acidente', 'hora_acidente',
#        'tp_rodovia', 'cond_pista', 'tp_cruzamento', 'tp_pavimento', 'tp_curva',
#        'lim_velocidade', 'tp_pista', 'ind_guardrail', 'ind_cantcentral',
#        'ind_acostamento', 'qtde_acidente', 'qtde_acid_com_obitos',
#        'qtde_envolvidos', 'qtde_feridosilesos', 'qtde_obitos'],
#       dtype='object')

# %% [markdown]
# #### Explorando localidades:

# %%
localidades.head(2)
# Out:
#    Unnamed: 0   chv_localidade  ano_referencia  mes_referencia  \
# 0        1104  AC1200393202201            2022               1
# 1        1105  AC1200179202201            2022               1
#
#    mes_ano_referencia regiao  uf  codigo_ibge     municipio  \
# 0               12022  NORTE  AC      1200393  PORTO WALTER
# 1               12022  NORTE  AC      1200179      CAPIXABA
#
#   regiao_metropolitana  qtde_habitantes  frota_total  frota_circulante
# 0                  nao            12497          394               295
# 1                  nao            12280         2677              2058

# %%
localidades.describe()
# Out:
#           Unnamed: 0  ano_referencia  mes_referencia  mes_ano_referencia  \
# count   67164.000000         67164.0    67164.000000        67164.000000
# mean   177470.371896          2022.0        6.500000        67022.000000
# std     97353.936859             0.0        3.452078        34520.782285
# min      1104.000000          2022.0        1.000000        12022.000000
# 25%    122822.750000          2022.0        3.750000        39522.000000
# 50%    167981.500000          2022.0        6.500000        67022.000000
# 75%    263444.250000          2022.0        9.250000        94522.000000
# max    335819.000000          2022.0       12.000000       122022.000000
#
#         codigo_ibge  qtde_habitantes   frota_total  frota_circulante
# count  6.716400e+04     6.716400e+04  6.716400e+04      6.716400e+04
# mean   3.237895e+06     3.823682e+04  2.023266e+04      1.357508e+04
# std    1.007983e+06     2.245515e+05  1.455164e+05      8.695565e+04
# min    0.000000e+00     0.000000e+00  0.000000e+00      0.000000e+00
# 25%    2.510402e+06     5.381000e+03  1.991000e+03      1.309000e+03
# 50%    3.145372e+06     1.164750e+04  4.254000e+03      2.781000e+03
# 75%    4.118709e+06     2.574825e+04  1.115925e+04      7.272000e+03
# max    5.300108e+06     1.246966e+07  9.148454e+06      5.059283e+06

# %%
localidades.columns
# Out:
# Index(['Unnamed: 0', 'chv_localidade', 'ano_referencia', 'mes_referencia',
#        'mes_ano_referencia', 'regiao', 'uf', 'codigo_ibge', 'municipio',
#        'regiao_metropolitana', 'qtde_habitantes', 'frota_total',
#        'frota_circulante'],
#       dtype='object')

# %% [markdown]
# #### Explorando tipo veiculos:

# %%
tipo_veiculos.head(2)
# Out:
#   num_acidente;tipo_veiculo;ind_veic_estrangeiro;qtde_veiculos
# 0                   57;NAO INFORMADO;NAO INFORMADO;1
# 1                   76;NAO INFORMADO;NAO INFORMADO;1

# %%
tipo_veiculos.describe()
# Out:
#        num_acidente;tipo_veiculo;ind_veic_estrangeiro;qtde_veiculos
# count                                             5189601
# unique                                            5189601
# top                   4584066;DESCONHECIDO;DESCONHECIDO;1
# freq                                                    1

# %%
tipo_veiculos.columns
# Out:
# Index(['num_acidente;tipo_veiculo;ind_veic_estrangeiro;qtde_veiculos'], dtype='object')

# %% [markdown]
# #### Explorando vitimas:

# %%
vitimas.head(2)
# Out:
#    Unnamed: 0  num_acidente   chv_localidade data_acidente uf_acidente  \
# 0       31977       4231902  AC1200401202201    2022-01-28          AC
# 1       31978       1889037  AC1200401202201    2022-01-08          AC
#
#    ano_acidente  mes_acidente  mes_ano_acidente         faixa_idade  \
# 0          2022             1             12022  ENTRE 18 E 24 ANOS
# 1          2022             1             12022       NAO INFORMADO
#
#           genero tp_envolvido gravidade_lesao equip_seguranca ind_motorista  \
# 0      MASCULINO    MOTORISTA   NAO INFORMADO   NAO INFORMADO           SIM
# 1  NAO INFORMADO    MOTORISTA   NAO INFORMADO   NAO INFORMADO           SIM
#
#      susp_alcool  qtde_envolvidos  qtde_feridosilesos  qtde_obitos
# 0  NAO INFORMADO                1                   1            0
# 1  NAO INFORMADO                1                   1            0

# %%
vitimas.describe()
# Out:
#          Unnamed: 0  num_acidente  ano_acidente  mes_acidente  \
# count  1.465440e+06  1.465440e+06     1465440.0  1.465440e+06
# mean   3.906723e+06  2.292301e+06        2022.0  6.142282e+00
# std    1.883160e+06  1.322630e+06           0.0  3.294830e+00
# min    3.197700e+04  1.000000e+00        2022.0  1.000000e+00
# 25%    3.226264e+06  1.147623e+06        2022.0  3.000000e+00
# 50%    3.592624e+06  2.292832e+06        2022.0  6.000000e+00
# 75%    5.737873e+06  3.435759e+06        2022.0  9.000000e+00
# max    7.008373e+06  4.588682e+06        2022.0  1.200000e+01
#
#        mes_ano_acidente  qtde_envolvidos  qtde_feridosilesos   qtde_obitos
# count      1.465440e+06     1.465440e+06        1.465440e+06  1.465440e+06
# mean       6.344482e+04     9.604399e-01        9.474943e-01  1.294560e-02
# std        3.294830e+04     3.232068e-01        3.394770e-01  1.163890e-01
# min        1.202200e+04     0.000000e+00        0.000000e+00  0.000000e+00
# 25%        3.202200e+04     1.000000e+00        1.000000e+00  0.000000e+00
# 50%        6.202200e+04     1.000000e+00        1.000000e+00  0.000000e+00
# 75%        9.202200e+04     1.000000e+00        1.000000e+00  0.000000e+00
# max        1.220220e+05     5.400000e+01        5.400000e+01  7.000000e+00

# %%
vitimas.columns
# Out:
# Index(['Unnamed: 0', 'num_acidente', 'chv_localidade', 'data_acidente',
#        'uf_acidente', 'ano_acidente', 'mes_acidente', 'mes_ano_acidente',
#        'faixa_idade', 'genero', 'tp_envolvido', 'gravidade_lesao',
#        'equip_seguranca', 'ind_motorista', 'susp_alcool', 'qtde_envolvidos',
#        'qtde_feridosilesos', 'qtde_obitos'],
#       dtype='object')

# %% [markdown]
# #### Trabalhando os dados:

# %%
rondonia = acidentes[acidentes['uf_acidente'] == 'RO']
rondonia.head(2)
# Out:
#         Unnamed: 0  num_acidente   chv_localidade data_acidente uf_acidente  \
# 597284     3142918        600642  RO1100049202201    2022-01-28          RO
# 597285     3142919        705720  RO1100205202201    2022-01-04          RO
#
#         ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 597284          2022             1             12022      1100049
# 597285          2022             1             12022      1100205
#
#          dia_semana  ... lim_velocidade       tp_pista  ind_guardrail  \
# 597284  SEXTA-FEIRA  ...  NAO INFORMADO  NAO INFORMADO  NAO INFORMADO
# 597285  TERCA-FEIRA  ...  NAO INFORMADO  NAO INFORMADO  NAO INFORMADO
#
#        ind_cantcentral  ind_acostamento  qtde_acidente qtde_acid_com_obitos  \
# 597284   NAO INFORMADO    NAO INFORMADO              1                    0
# 597285   NAO INFORMADO    NAO INFORMADO              1                    0
#
#         qtde_envolvidos  qtde_feridosilesos  qtde_obitos
# 597284                3                   3            0
# 597285                2                   2            0
#
# [2 rows x 36 columns]

# %%
merge_localidades = pd.merge(rondonia, localidades, on='chv_localidade')
merge_localidades.head(2)
# Out:
#    Unnamed: 0_x  num_acidente   chv_localidade data_acidente uf_acidente  \
# 0       3142918        600642  RO1100049202201    2022-01-28          RO
# 1       3142919        705720  RO1100205202201    2022-01-04          RO
#
#    ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge_x   dia_semana  \
# 0          2022             1             12022        1100049  SEXTA-FEIRA
# 1          2022             1             12022        1100205  TERCA-FEIRA
#
#    ... mes_referencia mes_ano_referencia regiao  uf  codigo_ibge_y  \
# 0  ...              1              12022  NORTE  RO        1100049
# 1  ...              1              12022  NORTE  RO        1100205
#
#      municipio regiao_metropolitana  qtde_habitantes  frota_total  \
# 0       CACOAL                  nao            86416        76029
# 1  PORTO VELHO                  nao           548952       302563
#
#    frota_circulante
# 0             56817
# 1            228599
#
# [2 rows x 48 columns]

# %%
# Agrupei pelos municipios e contei, peguei o num de acidentes e organizei alguns valores
total_acidentes = merge_localidades.groupby('municipio').count()['num_acidente'].sort_values(ascending=False)

total_acidentes
# Out:
# municipio
# PORTO VELHO                  5592
# JI-PARANA                    1374
# VILHENA                      1330
# CACOAL                        971
# ARIQUEMES                     966
# ROLIM DE MOURA                696
# JARU                          449
# PIMENTA BUENO                 405
# ESPIGAO D OESTE               266
# OURO PRETO DO OESTE           263
# GUAJARA-MIRIM                 185
# MACHADINHO D OESTE            175
# ALTA FLORESTA D OESTE         174
# SAO MIGUEL DO GUAPORE         158
# BURITIS                       143
# CANDEIAS DO JAMARI            143
# CEREJEIRAS                    127
# PRESIDENTE MEDICI             115
# COLORADO DO OESTE             102
# SAO FRANCISCO DO GUAPORE       99
# NOVA BRASILANDIA D OESTE       95
# ALVORADA D OESTE               94
# CUJUBIM                        93
# ALTO PARAISO                   82
# NOVA MAMORE                    82
# ITAPUA DO OESTE                71
# COSTA MARQUES                  60
# ALTO ALEGRE DOS PARECIS        59
# MONTE NEGRO                    57
# CHUPINGUAIA                    56
# THEOBROMA                      54
# CORUMBIARA                     53
# SERINGUEIRAS                   47
# SANTA LUZIA D OESTE            47
# MIRANTE DA SERRA               46
# NOVO HORIZONTE DO OESTE        44
# URUPA                          37
# VALE DO ANARI                  32
# SAO FELIPE D OESTE             31
# NOVA UNIAO                     31
# MINISTRO ANDREAZZA             30
# TEIXEIROPOLIS                  25
# VALE DO PARAISO                24
# CABIXI                         22
# PRIMAVERA DE RONDONIA          22
# GOVERNADOR JORGE TEIXEIRA      22
# CAMPO NOVO DE RONDONIA         21
# PARECIS                        15
# RIO CRESPO                     14
# PIMENTEIRAS DO OESTE           12
# CASTANHEIRAS                   11
# CACAULANDIA                     9
# Name: num_acidente, dtype: int64

# %%
# Quero fazer a media dos dados da população 
populacao_estadual = merge_localidades.groupby('municipio')['qtde_habitantes'].mean()
populacao_estadual
# Out:
# municipio
# ALTA FLORESTA D OESTE         22082.781609
# ALTO ALEGRE DOS PARECIS       13135.389831
# ALTO PARAISO                  22391.524390
# ALVORADA D OESTE              13438.840426
# ARIQUEMES                    111442.517598
# BURITIS                       41245.937063
# CABIXI                         4918.772727
# CACAULANDIA                    6284.444444
# CACOAL                        86024.110196
# CAMPO NOVO DE RONDONIA        14347.476190
# CANDEIAS DO JAMARI            28389.552448
# CASTANHEIRAS                   2853.727273
# CEREJEIRAS                    15833.259843
# CHUPINGUAIA                   11863.875000
# COLORADO DO OESTE             14772.911765
# CORUMBIARA                     6845.641509
# COSTA MARQUES                 19438.550000
# CUJUBIM                       27724.397849
# ESPIGAO D OESTE               32944.338346
# GOVERNADOR JORGE TEIXEIRA      6714.772727
# GUAJARA-MIRIM                 46789.994595
# ITAPUA DO OESTE               10863.521127
# JARU                          50868.345212
# JI-PARANA                    130621.702329
# MACHADINHO D OESTE            42058.017143
# MINISTRO ANDREAZZA             9274.433333
# MIRANTE DA SERRA              10480.673913
# MONTE NEGRO                   16130.824561
# NOVA BRASILANDIA D OESTE      20290.810526
# NOVA MAMORE                   32560.024390
# NOVA UNIAO                     6684.709677
# NOVO HORIZONTE DO OESTE        7858.727273
# OURO PRETO DO OESTE           34855.726236
# PARECIS                        6369.266667
# PIMENTA BUENO                 36924.441975
# PIMENTEIRAS DO OESTE           2094.333333
# PORTO VELHO                  551761.150215
# PRESIDENTE MEDICI             17597.739130
# PRIMAVERA DE RONDONIA          2587.045455
# RIO CRESPO                     3838.857143
# ROLIM DE MOURA                55491.074713
# SANTA LUZIA D OESTE            5636.787234
# SAO FELIPE D OESTE             4822.419355
# SAO FRANCISCO DO GUAPORE      21212.292929
# SAO MIGUEL DO GUAPORE         22992.854430
# SERINGUEIRAS                  11732.063830
# TEIXEIROPOLIS                  4073.360000
# THEOBROMA                     10208.314815
# URUPA                         10853.891892
# VALE DO ANARI                 11579.750000
# VALE DO PARAISO                6306.250000
# VILHENA                      105437.851128
# Name: qtde_habitantes, dtype: float64

# %%
resultado = total_acidentes/populacao_estadual *100
resultado.sort_values(ascending=False)
# Out:
# municipio
# VILHENA                      1.261407
# ROLIM DE MOURA               1.254256
# CACOAL                       1.128753
# PIMENTA BUENO                1.096834
# JI-PARANA                    1.051893
# PORTO VELHO                  1.013482
# JARU                         0.882671
# ARIQUEMES                    0.866815
# PRIMAVERA DE RONDONIA        0.850391
# SANTA LUZIA D OESTE          0.833808
# ESPIGAO D OESTE              0.807422
# CEREJEIRAS                   0.802109
# ALTA FLORESTA D OESTE        0.787944
# CORUMBIARA                   0.774215
# OURO PRETO DO OESTE          0.754539
# ALVORADA D OESTE             0.699465
# COLORADO DO OESTE            0.690453
# SAO MIGUEL DO GUAPORE        0.687170
# ITAPUA DO OESTE              0.653563
# PRESIDENTE MEDICI            0.653493
# SAO FELIPE D OESTE           0.642831
# TEIXEIROPOLIS                0.613744
# PIMENTEIRAS DO OESTE         0.572975
# NOVO HORIZONTE DO OESTE      0.559887
# THEOBROMA                    0.528981
# CANDEIAS DO JAMARI           0.503706
# CHUPINGUAIA                  0.472021
# NOVA BRASILANDIA D OESTE     0.468192
# SAO FRANCISCO DO GUAPORE     0.466711
# NOVA UNIAO                   0.463745
# ALTO ALEGRE DOS PARECIS      0.449168
# CABIXI                       0.447266
# MIRANTE DA SERRA             0.438903
# MACHADINHO D OESTE           0.416092
# SERINGUEIRAS                 0.400612
# GUAJARA-MIRIM                0.395384
# CASTANHEIRAS                 0.385461
# VALE DO PARAISO              0.380575
# ALTO PARAISO                 0.366210
# RIO CRESPO                   0.364692
# MONTE NEGRO                  0.353361
# BURITIS                      0.346701
# URUPA                        0.340892
# CUJUBIM                      0.335445
# GOVERNADOR JORGE TEIXEIRA    0.327636
# MINISTRO ANDREAZZA           0.323470
# COSTA MARQUES                0.308665
# VALE DO ANARI                0.276344
# NOVA MAMORE                  0.251843
# PARECIS                      0.235506
# CAMPO NOVO DE RONDONIA       0.146367
# CACAULANDIA                  0.143211
# dtype: float64
